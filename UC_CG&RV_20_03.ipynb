# %% [markdown]
# <a href="https://colab.research.google.com/github/pedromorais03/python-manipuling-images/blob/main/UC_CG%26RV_20_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pedro Henrique Morais Pereira - 822145369
# ---
# Felipe Mardoqueu Tavares N de Oliveira - 821135014
# ---
# João Victor Corado da Silva - 821117730
# ---
# Matheus Barbosa Machado - 824138536
# ---

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
imagem = cv2.imread("22_alterado.png")
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=390x294>

# %%
## aq os valores nao sao (x,y), sao (y,x)
altura = imagem.shape[0]
largura = imagem.shape[1]

# %%
print(f'A altura é {altura} e a largura é {largura}')
# Out:
# A altura é 560 e a largura é 681

# %%
## aq os valores nao sao (x,y), sao (y,x) e os valores da cor sao azul, verde e vermelho
(azul, verde, vermelho) = imagem[50, 63]
print(f'Vermelho: {vermelho} - Verde: {verde} - Azul: {azul}')
# Out:
# Vermelho: 163 - Verde: 129 - Azul: 127

# %%
imagem[65, 17] = (255,0,0)
imagem[24, 69] = (255,0,0)
imagem[24, 7] = (255,0,0)
imagem[140, 25] = (255,0,0)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=681x560>

# %%
cv2.imwrite("107_alterado.jpg", imagem)
# Out:
# True

# %%
img 10 - grupo 3
img 13 - grupo 6
img 22 - grupo 6
